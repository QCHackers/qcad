# %%
# !pip show QvsPy
# Out:
# Name: QvsPy
# Version: 0.0.1
# Summary: Quantum virus sensing on Python
# Home-page: https://github.com/SupertechLabs/cirq-superstaq
# Author: Super.tech
# Author-email: victory@super.tech
# License: Apache 2
# Location: /home/vtomole/NYUAD-2022-QSPirates
# Requires: amazon-braket-sdk, boto3, ibm-quantum-widgets, numpy, qiskit, wheel, notebook
# Required-by:

# %%
import qvspy

# %%
qs = qvspy.QuantumSensor()

# %% [markdown]
# Quantum Sensing for COVID Negative

# %%
exp1_data = qs.T1_experiment(37e-6)
display(exp1_data.figure(0))

# %% [markdown]
# Quantum Sensing for COVID Positive

# %%
exp2_data = qs.T1_experiment(126e-6)
display(exp2_data.figure(0))
