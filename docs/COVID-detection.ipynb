# %%
# !pip show QvsPy
# Out:
# Name: QvsPy
# Version: 1.0.0
# Summary: Quantum virus sensing on Python
# Home-page: https://github.com/Innanov/NYUAD-2022-QSPiratest
# Author: QS Pirates
# Author-email: victory@super.tech
# License: UNKNOWN
# Location: c:\users\phill\source\repos\nyuad-2022-qspirates\qvspy\qvspy
# Requires: numpy, qiskit, qiskit_experiments
# Required-by:

# %%
from qvspy import QuantumSensor

# %%
qs = QuantumSensor()

# %% [markdown]
# Quantum Sensing for COVID Negative

# %%
exp1_data = qs.T1_experiment(37e-6)
display(exp1_data.figure(0))

# %% [markdown]
# Quantum Sensing for COVID Positive

# %%
exp2_data = qs.T1_experiment(126e-6)
display(exp2_data.figure(0))
